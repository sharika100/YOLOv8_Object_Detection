# %% [markdown]
# <a href="https://colab.research.google.com/github/sharika100/YOLOv8_Object_Detection/blob/main/yolov8_object_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 28.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO('yolov8n.pt')  # Nano model (fastest)

# %%
# Step 4: Run detection on an image
image_url = 'https://ultralytics.com/images/bus.jpg'
results = model(image_url, save=True)  # Automatically saves annotated image
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 275.3ms
# Speed: 8.7ms preprocess, 275.3ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /content/runs/detect/predict

# %%
results = model(image_url, save=True)  # Run detection
results[0].show()  # Show the first result (works in Colab)
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 211.9ms
# Speed: 6.8ms preprocess, 211.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /content/runs/detect/predict
# <PIL.Image.Image image mode=RGB size=810x1080>

# %%
import glob
import IPython.display as display
from PIL import Image

# %%
output_files = glob.glob('runs/detect/predict/*.jpg')
for f in output_files:
    display.display(Image.open(f))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=810x1080>
